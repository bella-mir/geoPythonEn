# %% [markdown]
# # Assignment 5: How Much of the Population Each Amenity Serves
#
# In the **fifth module** you met raster data and **zonal statistics**, which aggregate raster values inside given geometries.
#
# In this assignment you will:
#
# 1. estimate how many people fall inside the 5, 10 and 15-minute catchment areas of one category of features;
# 2. work out what share of the population is left outside them;
# 3. wrap the calculation into a function;
# 4. apply it to every category you built catchment areas for in assignment 4.
#
# You will need:
#
# - the merged catchment areas built in assignment 4 for the different categories;
# - if useful, the individual zones per feature;
# - the boundary of your study area;
# - a WorldPop population raster.
#
# > The code cells below are placeholders for your own work: they are left unexecuted on purpose. Fill them in as you go, and run them in your own copy of the notebook.

# %% [markdown]
# ## Suggested Plan of Work
#
# ### Step 0. Importing Libraries

# %%
# your code

# %% [markdown]
# ### Step 1. Preparing the Data
#
# #### 1.1. Loading the Catchment Areas
#
# Load the `iso_<category>` layers from `project.gpkg` — the merged catchment areas you saved in the previous assignment, one row per time interval, with the interval in the `minutes` column.
#
# Load the `area` layer as well: you need it for the total population of the study area.

# %%
# your code

# iso_grocery = gpd.read_file("project.gpkg", layer="iso_grocery")
# area = gpd.read_file("project.gpkg", layer="area")

# %% [markdown]
# #### 1.2. Loading the Raster Data
#
# Download a raster from the WorldPop portal and clip it to your city — the workflow is in [Raster Data Format](../module_5/rasters_1.ipynb), sections 1 and 2.

# %%
# your code

# %% [markdown]
# Print its key properties:
#
# - CRS;
# - bounds;
# - resolution.

# %%
# your code

# %% [markdown]
# #### 1.3. Bringing the Data into One CRS
#
# Check that the raster and the catchment areas share the same CRS, and reproject if they do not.
#
# Note which layer you reproject. Every WorldPop pixel holds a **population count**, so reprojecting the raster changes those counts unless you resample with `Resampling.sum` — see [Raster Data Format](../module_5/rasters_1.ipynb), section 3.2. Reprojecting the vector zones into the CRS of the raster avoids the problem altogether.

# %%
# your code

# %% [markdown]
# ### Step 2. Counting the Population Inside the Catchment Areas
#
# This is where zonal statistics come in.

# %% [markdown]
# #### 2.1. Population Inside the Zones
#
# For each catchment area (5, 10, 15 minutes):
#
# - sum the raster values inside it — that is the population;
# - use `zonal_stats()`.

# %%
# your code

# %% [markdown]
# #### 2.2. Total Population of the Area
#
# Calculate the total population:
#
# - either of the whole raster;
# - or within the boundary of your study area.

# %%
# your code

# %% [markdown]
# #### 2.3. Population Outside the Catchment Areas
#
# Work out:
#
# - the population inside the zones;
# - the population outside them.

# %%
# your code

# %% [markdown]
# #### 2.4. Shares of the Population
#
# Calculate:
#
# - the share of the population inside the catchment areas;
# - the share outside them.

# %%
# your code

# %% [markdown]
# ### Step 3. Automating the Calculation for Every Category
#
# Now that you have the figures for one category, wrap the main steps into a function.
#
# The function should:
#
# 1. take as input:
#    - a `GeoDataFrame` with the merged catchment areas of one category;
#    - the path to the population raster;
#    - the total population of the study area;
#    - the name of the category;
#
# 2. for each catchment area:
#    - calculate the population inside the zone;
#    - calculate the population outside it;
#    - calculate the share of the population inside;
#    - calculate the share outside;
#
# 3. return a table of results.

# %%
# An outline of the function:

# def calculate_population_accessibility(
#     zones_gdf,
#     raster_path,
#     total_population,
#     category_name
# ):
#     """
#     Calculates the number and the share of people inside and outside
#     the catchment areas of one category of features.
#
#     The function should:
#     1. go through the 5, 10 and 15-minute zones;
#     2. sum the population inside each zone;
#     3. calculate the population outside it;
#     4. calculate the shares;
#     5. return a table of results.
#     """
#
#     # your code
#
#     return results_df

# %% [markdown]
# Then apply it to the catchment areas of every category:

# %%
# Example:

# all_results = []

# for category_name, zones_gdf in accessibility_zones.items():
#     result = calculate_population_accessibility(
#         zones_gdf=zones_gdf,
#         raster_path=population_raster_path,
#         total_population=total_population,
#         category_name=category_name
#     )

#     all_results.append(result)

# population_accessibility_results = pd.concat(all_results, ignore_index=True)

# %% [markdown]
# ### Step 4. Comparing the Categories
#
# With the function applied to every category, analyse the resulting table.
#
# Compare:
#
# - the population inside the catchment areas across categories;
# - the share of the population inside and outside the 5, 10 and 15-minute zones;
# - how much the coverage grows from 5 to 10 and from 10 to 15 minutes;
# - the categories with the widest and the narrowest coverage.
#
# A visualisation helps here — a bar chart of the share of the population inside the catchment areas by category, for example.

# %%
# your code

# %% [markdown]
# ### Step 5. Buildings or People?
#
# In [assignment 3](../module_3/geopy_task3.ipynb) you measured access as a **share of buildings**; here you measure it as a **share of the population**. The two rarely agree, and the difference is informative.
#
# Take the stop catchment areas from assignment 3 (`stops_catchment` in `project.gpkg`) and run your population function on them, then put the two figures side by side:
#
# - the share of buildings inside the catchment areas;
# - the share of the population inside the same areas.
#
# If the population share is the higher of the two, the buildings outside the zones are the small ones — the population is concentrated where the transport is. If it is lower, whole residential blocks are sitting outside. Which of the two numbers would you put in a report, and why?

# %%
# your code

# %% [markdown]
# > _your notes here_

# %% [markdown]
# ### Step 6. Visualising the Results
#
# Build the visualisations that make the comparison readable. For example:
#
# - the catchment areas of one or several categories on a map;
# - a bar chart of the share of the population served, by category;
# - the coverage at 5, 10 and 15 minutes side by side;
# - a map of the areas that stay outside every catchment area.
#
# Put the `landuse` layer from assignment 2 under that last map. Where the gaps fall on residential land use, they are a real accessibility problem; where they fall on industrial land, forest or water, they are not. This is the point where the land use analysis pays off.

# %%
# your code

# %% [markdown]
# ### Step 7. Analysing the Results
#
# Using the figures you calculated, answer the questions:
#
# - For which categories is the share of the population within a 15-minute walk the highest?
# - For which categories does the largest share of the population stay outside?
# - How much does the coverage grow from 5 to 10 and from 10 to 15 minutes?
# - Are there categories where even the 15-minute zone covers only a small part of the population?
# - Which differences between categories look the most significant?
# - Do the results match what you expected?

# %% [markdown]
# > _your notes here_

# %% [markdown]
# ### Step 8. Limitations of the Method
#
# Briefly describe the limitations worth keeping in mind when interpreting the results:
#
# - WorldPop figures are modelled estimates rather than counts;
# - the resolution of the raster limits how precise the numbers can be;
# - catchment areas built with `convex_hull` are approximations;
# - mismatches between the CRS of the raster and of the vector data, and resampling of population counts during reprojection;
# - the influence of the raster, study area and catchment area boundaries;
# - catchment areas of features in the same category overlap;
# - OSM data quality differs from one category of features to another.

# %% [markdown]
# > _your notes here_

# %% [markdown]
# ### Step 9. Saving the Results
#
# Save the results so you can reuse them:
#
# - the final table with the figures for every category and time interval — as a CSV next to `project.gpkg`, `population_accessibility.csv` for example;
# - the catchment areas with the population figures attached — write them back over the `iso_<category>` layers, so the numbers travel with the geometry.
#
# [Assignment 6](../module_6/geopy_task6.ipynb) shows those figures in the tooltips of the final map, so keep the column names simple and stable: `population_inside`, `share_inside`.

# %%
# your code

# %% [markdown]
# ## Result
#
# By the end of this assignment you should have:
#
# - the population inside the 5, 10 and 15-minute catchment areas of one chosen category;
# - the number and the share of the population left outside them;
# - a function that calculates those figures for any category;
# - a comparison table covering every category of features;
# - coverage figures by category and time interval;
# - a visualisation of the differences between categories;
# - a comparison of the population-based figures with the building-based ones from assignment 3;
# - an interpretation of the results that accounts for the limitations of the method;
# - the results table saved as CSV and the population figures written into the `iso_<category>` layers.
