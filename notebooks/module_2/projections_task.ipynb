# %% [markdown]
# # Assignment 2: Mapping Land Use
#
# In the **second module** we met coordinate reference systems and map projections, learned to reproject data between them, and calculated areas and distances.
#
# In this assignment you will explore the **land use structure** of your study area using **OpenStreetMap** data. It gives you a better sense of how the district is organised in space, and lays the groundwork for the analysis of the urban environment in the **15-minute city** project.
#
# Along the way we will:
#
# - download land use data from OpenStreetMap for the study area chosen earlier;
# - explore the structure and content of that data;
# - clean and prepare it for analysis;
# - reproject it into a suitable coordinate reference system;
# - calculate the area of each land use type;
# - visualise the results.
#
# > The code cells below are placeholders for your own work: they are left unexecuted on purpose. Fill them in as you go, and run them in your own copy of the notebook.

# %% [markdown]
# ## Suggested Steps

# %% [markdown]
# ### Step 0. Importing Libraries
#
# Import everything you will need for the assignment.

# %%
import osmnx as ox

# keep all downloaded OSM responses in one cache folder at the root of the repository
ox.settings.cache_folder = "../../cache"

# add the other libraries here

# %% [markdown]
# ### Step 1. Downloading Land Use Data from OSM
#
# #### 1.1. Defining the Study Area
#
# Put the name of your study area into `area_name` — the same district you worked with in the first assignment.
#
# Its boundary is already in `project.gpkg` as the `area` layer (see the data layout at the top of [assignment 1](../module_1/spData_task.ipynb)); load it if you want to check the extent or clip the result to it.

# %%
area_name = ""  # the name of your district or town

# area = gpd.read_file("project.gpkg", layer="area")

# %% [markdown]
# #### 1.2. Defining the OSM Tags
#
# Set the OSM tags for land use. Here we are interested in features carrying the `landuse` key — see the OSM [Map Features](https://wiki.openstreetmap.org/wiki/Map_features) documentation.

# %%
# tags = ...

# %% [markdown]
# #### 1.3. Downloading the Data
#
# Download the land use features for your area with `ox.features_from_place()`.

# %%
# landuse = ...

# %% [markdown]
# ### Step 2. Exploring the Data
#
# Before any analysis, it is worth understanding what the downloaded dataset actually contains.
#
# Run the following checks on the `landuse` dataset — they are the ones from [Exploring a Dataset](../module_1/spData_3.ipynb).

# %% [markdown]
# #### 2.1. Visualisation
#
# Look at the land use features on a map.

# %%
# your code

# %% [markdown]
# #### 2.2. Number of Features
#
# Find out how many features the dataset contains.

# %%
# your code

# %% [markdown]
# #### 2.3. Attributes
#
# Examine the structure of the table:
#
# - which fields it has;
# - which of them carry information useful for the analysis;
# - which field holds the land use type.

# %%
# your code

# %% [markdown]
# #### 2.4. Geometry Types
#
# Check which geometry types are present in the data.
#
# If your goal is to measure areas, it matters whether the dataset contains only polygons or points and lines as well.

# %%
# your code

# %% [markdown]
# #### 2.5. Unique Land Use Types
#
# Look at the values stored in the `landuse` field.
#
# This tells you which land use types occur in your study area.

# %%
# your code

# %% [markdown]
# ### Step 3. Preparing the Data
#
# Get the data ready for analysis.
#
# #### 3.1. Filtering by Geometry Type
#
# Keep only features with `Polygon` and `MultiPolygon` geometry — areas can only be calculated correctly for those.

# %%
# your code

# %% [markdown]
# #### 3.2. Selecting Attributes
#
# Drop the columns you do not need and keep the ones that will be useful later.
#
# You **must keep the geometry column** (`geometry`), and we also recommend keeping:
#
# - the OSM identifier. In OSMnx it lives in the index rather than in a column, so extract it first, as in [Exporting Data from OSM](../module_1/spData_4.ipynb), section 4.3:
#
#   ```python
#   landuse["osm_id"] = landuse.index.get_level_values("id")
#   ```
#
# - `landuse`;
# - any other useful fields the dataset happens to have.

# %%
# your code

# %% [markdown]
# ### Step 4. Reprojecting the Data
#
# To measure areas, the data must be in a **projected coordinate reference system** with metric units — not in a geographic one.
#
# #### 4.1. Choosing a Suitable CRS
#
# Find the appropriate UTM zone for your study area.

# %%
# your code

# %% [markdown]
# #### 4.2. Reprojecting
#
# Reproject the land use data into that CRS.

# %%
# your code

# %% [markdown]
# ### Step 5. Calculating Areas by Land Use Type
#
# #### 5.1. Area of Each Feature
#
# Calculate the area of every polygon in square metres.

# %%
# your code

# %% [markdown]
# #### 5.2. Aggregating by Land Use Type
#
# Group the data by the `landuse` field and calculate:
#
# - the total area of each land use type;
# - the share of each type in the total area of all land use features.
#
# _Hint:_ pandas `groupby()` does the grouping; dividing a column by its own sum gives the shares.

# %%
# your code

# %% [markdown]
# ### Step 6. Visualising the Results
#
# #### 6.1. Land Use Map
#
# Build a map where different land use types are shown in different colours.
#
# Work out how to do this yourself: `explore()` takes a `column` argument that colours features by the values of that column. Here the column is categorical rather than numeric, so pay attention to how the colours are assigned — we come back to thematic maps in the third module.

# %%
# your code

# %% [markdown]
# #### 6.2. Chart
#
# Build a pie chart showing the relative share of each land use type.
#
# _Hint:_ a pandas `Series` has a `.plot.pie()` method, which uses `matplotlib` under the hood.

# %%
# your code

# %% [markdown]
# ### Step 7. Saving the Data
#
# Save the prepared land use data, together with the calculated areas, as the `landuse` layer of `project.gpkg`.
#
# This one is not optional: [assignment 3](../module_3/geoprocessing_task.ipynb) uses the land use layer to work out which buildings are residential, and [assignment 6](../module_6/map_task.ipynb) puts it on the final map. Remember the storage rule — write it back in EPSG:4326, and reproject to UTM when you need to measure something.

# %%
# your code

# landuse.to_crs("EPSG:4326").to_file("project.gpkg", layer="landuse", driver="GPKG")

# %% [markdown]
# ### Step 8. Interpreting the Results
#
# Look at the map and the table of results, and answer a few questions.
#
# #### 8.1. Data Quality
#
# - How complete does the land use data look to you?
# - Are there gaps, unexpected empty spaces, or suspicious patches?
# - Does the map match the real structure of the district?
#
# #### 8.2. Structure of the Area
#
# - Which land use types dominate your study area?
# - What does that say about the character of the district — is it residential, industrial, mixed, recreational?
# - Is one use crowding out the others?
#
# #### 8.3. Connection with the 15-Minute City
#
# Think about how the land use structure relates to the accessibility of everyday amenities. For example:
#
# - are there enough residential and commercial or civic zones;
# - are there green areas;
# - how mixed the uses are;
# - can a structure like this support everyday life within walking distance?

# %% [markdown]
# > _your notes here_

# %% [markdown]
# ## What You Should Have
#
# By the end of this assignment you should have:
#
# - cleaned land use data;
# - that data reprojected into a suitable coordinate reference system;
# - the area calculated for each land use type;
# - a map and a chart showing the land use structure of your study area;
# - the `landuse` layer saved in `project.gpkg` for the assignments that follow.
